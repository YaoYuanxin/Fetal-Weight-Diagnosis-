# %%
import pandas as pd
penguins_cleaned = pd.read_csv("/workspaces/Fetal-Weight-Diagnosis-/peguine_data.csv")
penguins_cleaned
# Out:
#      Unnamed: 0    species     island  bill_length_mm  bill_depth_mm  \
# 0             0     Adelie  Torgersen            39.1           18.7
# 1             1     Adelie  Torgersen            39.5           17.4
# 2             2     Adelie  Torgersen            40.3           18.0
# 3             3     Adelie  Torgersen            36.7           19.3
# 4             4     Adelie  Torgersen            39.3           20.6
# ..          ...        ...        ...             ...            ...
# 328         328  Chinstrap      Dream            55.8           19.8
# 329         329  Chinstrap      Dream            43.5           18.1
# 330         330  Chinstrap      Dream            49.6           18.2
# 331         331  Chinstrap      Dream            50.8           19.0
# 332         332  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex
# 0                  181         3750    male
# 1                  186         3800  female
# ...
